# %%
a=[15, 15.6, 5+8j, None, False, [6, 8], 'ok', (1, 2), {3, 4}, {1: 2, 3: 4}]

# %%
for i in a:
  print(f"{i} имеет тип {type(i)}")
# Out:
# 15 имеет тип <class 'int'>
# 15.6 имеет тип <class 'float'>
# (5+8j) имеет тип <class 'complex'>
# None имеет тип <class 'NoneType'>
# False имеет тип <class 'bool'>
# [6, 8] имеет тип <class 'list'>
# ok имеет тип <class 'str'>
# (1, 2) имеет тип <class 'tuple'>
# {3, 4} имеет тип <class 'set'>
# {1: 2, 3: 4} имеет тип <class 'dict'>
